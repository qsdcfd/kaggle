# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('./input/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Embarked--> Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_87d3a_row0_col0, #T_87d3a_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_87d3a_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_87d3a_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_87d3a_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_87d3a_row0_col4, #T_87d3a_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_87d3a_row1_col0, #T_87d3a_row3_col0, #T_87d3a_row3_col1, #T_87d3a_row3_col2, #T_87d3a_row3_col3, #T_87d3a_row3_col4, #T_87d3a_row4_col0, #T_87d3a_row4_col2, #T_87d3a_row4_col3, #T_87d3a_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_87d3a_row1_col1, #T_87d3a_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_87d3a_row1_col3, #T_87d3a_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_87d3a_row2_col0, #T_87d3a_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_87d3a_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_87d3a_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_87d3a_row2_col4, #T_87d3a_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_87d3a_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_87d3a_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_87d3a_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_87d3a_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_87d3a_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_87d3a_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_87d3a_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_87d3a_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_87d3a_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_87d3a_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_87d3a_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_87d3a_row7_col3, #T_87d3a_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_87d3a_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_87d3a_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_87d3a_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_87d3a_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_87d3a_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_87d3a_row9_col0, #T_87d3a_row9_col1, #T_87d3a_row9_col2, #T_87d3a_row9_col3, #T_87d3a_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_87d3a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th class="col_heading level0 col0" colspan="2">female</th>
#       <th class="col_heading level0 col2" colspan="2">male</th>
#       <th class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="col_heading level1 col0" >0</th>
#       <th class="col_heading level1 col1" >1</th>
#       <th class="col_heading level1 col2" >0</th>
#       <th class="col_heading level1 col3" >1</th>
#       <th class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87d3a_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_87d3a_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_87d3a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_87d3a_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_87d3a_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_87d3a_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_87d3a_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_87d3a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_87d3a_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_87d3a_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_87d3a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_87d3a_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_87d3a_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_87d3a_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_87d3a_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_87d3a_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_87d3a_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_87d3a_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_87d3a_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_87d3a_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_87d3a_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_87d3a_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_87d3a_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_87d3a_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_87d3a_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_87d3a_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_87d3a_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_87d3a_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_87d3a_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_87d3a_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_87d3a_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_87d3a_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_87d3a_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_87d3a_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_87d3a_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_87d3a_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_87d3a_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_87d3a_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_87d3a_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_87d3a_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_87d3a_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_87d3a_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_87d3a_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_87d3a_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_87d3a_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_87d3a_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_87d3a_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_87d3a_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_87d3a_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_87d3a_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_87d3a_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_87d3a_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_87d3a_row9_col1" class="data row9 col1" >231</td>
#       <td id="T_87d3a_row9_col2" class="data row9 col2" >468</td>
#       <td id="T_87d3a_row9_col3" class="data row9 col3" >

# %% [markdown]
# #### 선착장에 따른 생존율

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked', data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=data, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# S에 가장 많은 탑승객이 있고, 대다수가 Pclass3에 속하였습니다.
#
# Pclass1과 Pclass2가 구조되기 적절한 위치이다.

# %% [markdown]
# #### Filling Embarked NaN

# %%
data['Embarked'].fillna('S',inplace=True)
data.Embarked.isnull().any #NaN값이 없다
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool>

# %% [markdown]
# #### SibSip-->Discrete Feature
#
# Sibling = brother, sister, stepbrother, stepsister
#
# Spouse = husband, wife

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_3b188_row0_col0, #T_3b188_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_3b188_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_3b188_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_3b188_row2_col0, #T_3b188_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_3b188_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_3b188_row3_col0, #T_3b188_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_3b188_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_3b188_row5_col0, #T_3b188_row5_col1, #T_3b188_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3b188_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_3b188_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b188_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b188_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_3b188_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_3b188_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b188_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_3b188_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_3b188_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b188_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_3b188_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_3b188_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3b188_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_3b188_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3b188_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3b188_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_3b188_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3b188_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3b188_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_3b188_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3b188_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_3b188_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_3b188_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')

plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_23725_row0_col0, #T_23725_row0_col1, #T_23725_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_23725_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_23725_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_23725_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_23725_row2_col0, #T_23725_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_23725_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_23725_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_23725_row3_col0, #T_23725_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_23725_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_23725_row4_col0, #T_23725_row4_col1, #T_23725_row5_col0, #T_23725_row5_col1, #T_23725_row5_col2, #T_23725_row6_col0, #T_23725_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_23725_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_23725_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23725_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23725_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_23725_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_23725_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_23725_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23725_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_23725_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_23725_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_23725_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23725_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_23725_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_23725_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_23725_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23725_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_23725_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_23725_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_23725_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23725_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_23725_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_23725_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_23725_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_23725_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_23725_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_23725_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_23725_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_23725_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_23725_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_23725_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_dab99_row0_col0, #T_dab99_row0_col1, #T_dab99_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_dab99_row1_col0 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_dab99_row1_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_dab99_row1_col2 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_dab99_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_dab99_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_dab99_row2_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_dab99_row3_col0, #T_dab99_row4_col1, #T_dab99_row5_col0, #T_dab99_row5_col1, #T_dab99_row6_col0, #T_dab99_row6_col1, #T_dab99_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_dab99_row3_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_dab99_row3_col2, #T_dab99_row4_col0, #T_dab99_row4_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_dab99_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# </style>
# <table id="T_dab99_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dab99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dab99_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_dab99_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_dab99_row0_col2" class="data row0 col2" >381</td>
#     </tr>
#     <tr>
#       <th id="T_dab99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dab99_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_dab99_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_dab99_row1_col2" class="data row1 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_dab99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dab99_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_dab99_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_dab99_row2_col2" class="data row2 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_dab99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dab99_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_dab99_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_dab99_row3_col2" class="data row3 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dab99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dab99_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_dab99_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_dab99_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dab99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dab99_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_dab99_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_dab99_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dab99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dab99_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_dab99_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_dab99_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data, ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(0)
plt.show()

# %% [markdown]
# #### Fare--> Continous Feature

# %%
print('Highest Fare was:', data['Fare'].max())
print('Lowest Fare was:', data['Fare'].min())
print('Average Fare was;', data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was; 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20, 8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare, ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# #### Correlation Between The Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) # correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()
